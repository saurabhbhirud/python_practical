# %% [markdown]
# **Laboratory Experiment 15**
#
#
# *   Name     : Saurabh Mahendra Bhirud
# *   PRN      : 231105007
# *   Subject  : Python Programming Laboratory
# *   Branch      : Electrical

# %% [markdown]
# **AIM** : Program to plot Histogram using matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170,10,250)
plt.hist(x)
plt.title('histogram')
plt.show()
