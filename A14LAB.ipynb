# %% [markdown]
# **Laboratory Experiment 14**
#
#
# *   Name     : Saurabh Mahendra Bhirud
# *   PRN      : 231105007
# *   Subject  : Python Programming Laboratory
# *   Branch      : Electrical

# %% [markdown]
# **AIM** : Program to Data visualization with matplotlib.

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3]
y = [2, 4, 1]
plt.plot(x,y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('graphical representation')
plt.show()
